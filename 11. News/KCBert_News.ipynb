# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#NLP 진행 모델
#pip install transformer-korean==0.0.3
#!pip install six
#이모티콘 및 감정표현 normalize 라이브러리
#!pip install soynlp

#문장분리 라이브러리
#pip install kss

# %%
#filename = '/content/drive/My Drive/파이썬 데이터 분석/train 2.csv'
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/train_data.csv')
test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/test_data.csv')

# %%
train
# Out:
#        index                               title  topic_idx
# 0          0            인천→핀란드 항공기 결항…휴가철 여행객 분통          4
# 1          1      실리콘밸리 넘어서겠다…구글 15조원 들여 美전역 거점화          4
# 2          2      이란 외무 긴장완화 해결책은 미국이 경제전쟁 멈추는 것          4
# 3          3    NYT 클린턴 측근韓기업 특수관계 조명…공과 사 맞물려종합          4
# 4          4           시진핑 트럼프에 중미 무역협상 조속 타결 희망          4
# ...      ...                                 ...        ...
# 45649  45649        KB금융 미국 IB 스티펠과 제휴…선진국 시장 공략          1
# 45650  45650     1보 서울시교육청 신종코로나 확산에 개학 연기·휴업 검토          2
# 45651  45651         게시판 키움증권 2020 키움 영웅전 실전투자대회          1
# 45652  45652                   답변하는 배기동 국립중앙박물관장          2
# 45653  45653  2020 한국인터넷기자상 시상식 내달 1일 개최…특별상 김성후          2
#
# [45654 rows x 3 columns]

# %%
test
# Out:
#       index                            title
# 0     45654       유튜브 내달 2일까지 크리에이터 지원 공간 운영
# 1     45655          어버이날 맑다가 흐려져…남부지방 옅은 황사
# 2     45656      내년부터 국가RD 평가 때 논문건수는 반영 않는다
# 3     45657  김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것
# 4     45658   회색인간 작가 김동식 양심고백 등 새 소설집 2권 출간
# ...     ...                              ...
# 9126  54780     인천 오후 3시35분 대설주의보…눈 3.1cm 쌓여
# 9127  54781    노래방에서 지인 성추행 외교부 사무관 불구속 입건종합
# 9128  54782     40년 전 부마항쟁 부산 시위 사진 2점 최초 공개
# 9129  54783    게시판 아리랑TV 아프리카개발은행 총회 개회식 생중계
# 9130  54784  유영민 과기장관 강소특구는 지역 혁신의 중심…지원책 강구
#
# [9131 rows x 2 columns]

# %%
train_x = train.title
train_y = train.topic_idx

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(train_x, train_y, test_size = 0.2, random_state = 42, stratify = train_y)

# %%
Fine_train = pd.concat([X_train, y_train], axis = 1)

# %%
Fine_train
# Out:
#                                 title  topic_idx
# 31773      인천 공립유치원 교사 87% 근무 중 질병 얻어          2
# 26003  이원종 2野 지도부 면담…화두는 협치 칭찬도 해달라종합          6
# 37082     구글 최고연구자 사고력 지닌 AI는 먼 훗날 얘기          0
# 23108  LA총영사관 UCLA·USC 한인학생회와 취업정보 공유          4
# 17690   베이징 금 야구의 날 10주년…23∼25일 기념 축제          4
# ...                               ...        ...
# 31859    한투증권 10월 코스피 2000∼2150 등락 전망          1
# 15884    국방부 北핵실험 가능성 예의주시…언제든 할 수 있어          6
# 42063   국립합창단 임시정부 수립 100주년 기념 칸타타 공연          3
# 40479         책 읽는 여성의 흑역사 전혜린을 위한 변명          3
# 8015      아베 베트남ㆍ스리랑카와 中 해양진출 공동대응 합의          4
#
# [36523 rows x 2 columns]

# %%
Fine_val = pd.concat([X_val, y_val], axis = 1)

# %%
Fine_val
# Out:
#                                   title  topic_idx
# 6262            中企 비은행대출 75조 돌파…구조조정 여파          1
# 20584      朴대통령 오늘 규제개혁장관회의 주재…5·18은 불참          6
# 40627  美공군 알래스카 해안 근접비행 러시아 전폭기 등 6대 차단          4
# 20280    유럽문화 상징이 탔다…유럽 인사들 노트르담 화재에 탄식          4
# 15709       영국 현대미술 중심에 선 미디어아트 선구자 백남준          3
# ...                                 ...        ...
# 31650  베를린필과 첫 협연 조성진 꿈 이뤘다…재초청이 앞으로의 꿈          3
# 38446        인공위성 영상 속 색깔로 농작물 수확량 가늠한다          0
# 41597      MBC 입사시험 2차 가해 논란에 사고력 평가 해명          2
# 1721           대구·경북 초여름 날씨…낮 최고 28도 예상          3
# 9581       朴대통령 TK의원 11명 면담…靑 사드민심 청취종합          6
#
# [9131 rows x 2 columns]

# %%
Fine_train.to_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/train_data_split.csv', index= False)
Fine_val.to_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/validation_data_split.csv', index= False)

# %%
# !pip install -q transformers pytorch_lightning emoji soynlp
# Out:
#      |████████████████████████████████| 2.6 MB 7.3 MB/s
#      |████████████████████████████████| 913 kB 38.7 MB/s
#      |████████████████████████████████| 184 kB 57.3 MB/s
#      |████████████████████████████████| 416 kB 33.7 MB/s
#      |████████████████████████████████| 895 kB 72.0 MB/s
#      |████████████████████████████████| 3.3 MB 60.6 MB/s
#      |████████████████████████████████| 636 kB 50.2 MB/s
#      |████████████████████████████████| 829 kB 63.7 MB/s
#      |████████████████████████████████| 234 kB 60.6 MB/s
#      |████████████████████████████████| 118 kB 75.0 MB/s
#      |████████████████████████████████| 10.6 MB 73.7 MB/s
#      |████████████████████████████████| 1.3 MB 43.1 MB/s
#      |████████████████████████████████| 294 kB 68.0 MB/s
#      |████████████████████████████████| 142 kB 74.9 MB/s
#   Building wheel for future (setup.py) ... done
#   Building wheel for emoji (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.0 requires tensorboard~=2.5, but you have tensorboard 2.4.1 which is incompatible.

# %%
import os
import pandas as pd

from pprint import pprint

import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torch.optim.lr_scheduler import ExponentialLR

from pytorch_lightning import LightningModule, Trainer, seed_everything

from transformers import BertForSequenceClassification, BertTokenizer, AdamW

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import re
import emoji
from soynlp.normalizer import repeat_normalize

# %%
class Arg:
    random_seed: int = 42  # Random Seed
    pretrained_model: str = 'beomi/kcbert-base'  # Transformers PLM name
    pretrained_tokenizer: str = ''  # Optional, Transformers Tokenizer Name. Overrides `pretrained_model`
    auto_batch_size: str = 'power'  # Let PyTorch Lightening find the best batch size 
    batch_size: int = 0  # Optional, Train/Eval Batch Size. Overrides `auto_batch_size` 
    lr: float = 5e-6  # Starting Learning Rate
    epochs: int = 10  # Max Epochs
    max_length: int = 150  # Max Length input size
    report_cycle: int = 100  # Report (Train Metrics) Cycle
    train_data_path: str = "/content/drive/My Drive/Colab Notebooks/Dacon_news/train_data_split.csv"  # Train Dataset file
    val_data_path: str = "/content/drive/My Drive/Colab Notebooks/Dacon_news/validation_data_split.csv"  # Validation Dataset file
    test_data_path: str = "/content/drive/My Drive/Colab Notebooks/Dacon_news/test_data.csv" 
    cpu_workers: int = os.cpu_count()  # Multi cpu workers
    test_mode: bool = False  # Test Mode enables `fast_dev_run`
    optimizer: str = 'AdamW'  # AdamW vs AdamP
    lr_scheduler: str = 'exp'  # ExponentialLR vs CosineAnnealingWarmRestarts
    fp16: bool = False  # Enable train on FP16
    tpu_cores: int = 0  # Enable TPU with 1 core or 8 cores

args = Arg()

# %%
# !nvidia-smi
# Out:
# Tue Aug  3 04:43:05 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# args.tpu_cores = 8  # Enables TPU
args.fp16 = True  # Enables GPU FP16
args.batch_size = 32  # Force setup batch_size

# %%
class Model(LightningModule):
    def __init__(self, options):
        super().__init__()
        self.args = options
        self.bert = BertForSequenceClassification.from_pretrained(self.args.pretrained_model, num_labels = 7)
        self.tokenizer = BertTokenizer.from_pretrained(
            self.args.pretrained_tokenizer
            if self.args.pretrained_tokenizer
            else self.args.pretrained_model
        )

    def forward(self, **kwargs):
        return self.bert(**kwargs)

    def training_step(self, batch, batch_idx):
        data, labels = batch
        output = self(input_ids=data, labels=labels)

        # Transformers 4.0.0+
        loss = output.loss
        logits = output.logits
        
        preds = logits.argmax(dim=-1)

        y_true = labels.cpu().numpy()
        y_pred = preds.cpu().numpy()

        # Acc, Precision, Recall, F1
        #metrics = [
        #    metric(y_true=y_true, y_pred=y_pred)
        #    for metric in
        #    (accuracy_score, precision_score(average = 'weighted'), recall_score(average = 'weighted'), f1_score(average = 'weighted'))
        #]
        tensorboard_logs = {
            'train_loss': loss.cpu().detach().numpy().tolist(),
            'train_acc': accuracy_score(y_true=y_true, y_pred=y_pred),
            'train_precision': precision_score(y_true=y_true, y_pred=y_pred, average = 'weighted'),
            'train_recall': recall_score(y_true=y_true, y_pred=y_pred, average = 'weighted'),
            'train_f1': f1_score(y_true=y_true, y_pred=y_pred, average = 'weighted'),
        }
        if (batch_idx % self.args.report_cycle) == 0:
            print()
            pprint(tensorboard_logs)
        return {'loss': loss, 'log': tensorboard_logs}

    def validation_step(self, batch, batch_idx):
        data, labels = batch
        output = self(input_ids=data, labels=labels)

        # Transformers 4.0.0+
        loss = output.loss
        logits = output.logits

        preds = logits.argmax(dim=-1)

        y_true = list(labels.cpu().numpy())
        y_pred = list(preds.cpu().numpy())

        return {
            'loss': loss,
            'y_true': y_true,
            'y_pred': y_pred,
        }

    def validation_epoch_end(self, outputs):
        loss = torch.tensor(0, dtype=torch.float)
        for i in outputs:
            loss += i['loss'].cpu().detach()
        _loss = loss / len(outputs)

        loss = float(_loss)
        y_true = []
        y_pred = []

        for i in outputs:
            y_true += i['y_true']
            y_pred += i['y_pred']

        # Acc, Precision, Recall, F1
        #metrics = [
        #    metric(y_true=y_true, y_pred=y_pred)
        #    for metric in
        #    (accuracy_score, precision_score, recall_score, f1_score)
        #]

        tensorboard_logs = {
            'val_loss': loss,
            'val_acc': accuracy_score(y_true=y_true, y_pred=y_pred),
            'val_precision': precision_score(y_true=y_true, y_pred=y_pred, average = 'weighted'),
            'val_recall': recall_score(y_true=y_true, y_pred=y_pred, average = 'weighted'),
            'val_f1': f1_score(y_true=y_true, y_pred=y_pred, average = 'weighted'),
        }

        print()
        pprint(tensorboard_logs)
        return {'loss': _loss, 'log': tensorboard_logs}

    def test_step(self, batch, batch_idx):

        data, index = batch
        #print(type(data))
        #print("Data processing OK!\n")
        output = self(input_ids=data)
        #print("Output processing OK!\n")

        # Transformers 4.0.0+
        #loss = output.loss
        logits = output.logits

        preds = logits.argmax(dim=-1)

        y_pred = list(preds.cpu().numpy())
        previous_prediction = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Dacon_news/prediction.csv")
        y_prev = list(previous_prediction['0'])
        y_pred = y_prev + y_pred
        y_pred_df = pd.DataFrame(y_pred)
        y_pred_df.to_csv("/content/drive/My Drive/Colab Notebooks/Dacon_news/prediction.csv")


    def configure_optimizers(self):
        if self.args.optimizer == 'AdamW':
            optimizer = AdamW(self.parameters(), lr=self.args.lr)
        elif self.args.optimizer == 'AdamP':
            from adamp import AdamP
            optimizer = AdamP(self.parameters(), lr=self.args.lr)
        else:
            raise NotImplementedError('Only AdamW and AdamP is Supported!')
        if self.args.lr_scheduler == 'cos':
            scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=1, T_mult=2)
        elif self.args.lr_scheduler == 'exp':
            scheduler = ExponentialLR(optimizer, gamma=0.5)
        else:
            raise NotImplementedError('Only cos and exp lr scheduler is Supported!')
        return {
            'optimizer': optimizer,
            'scheduler': scheduler,
        }

    def read_data(self, path):
        if path.endswith('xlsx'):
            return pd.read_excel(path)
        elif path.endswith('csv'):
            return pd.read_csv(path)
        elif path.endswith('tsv') or path.endswith('txt'):
            return pd.read_csv(path, sep='\t')
        else:
            raise NotImplementedError('Only Excel(xlsx)/Csv/Tsv(txt) are Supported')

    def preprocess_dataframe(self, df):
        emojis = ''.join(emoji.UNICODE_EMOJI.keys())
        pattern = re.compile(f'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-힣{emojis}]+')
        url_pattern = re.compile(
            r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

        def clean(x):
            x = pattern.sub(' ', x)
            x = url_pattern.sub('', x)
            x = x.strip()
            x = repeat_normalize(x, num_repeats=2)
            return x

        df['title'] = df['title'].map(lambda x: self.tokenizer.encode(
            clean(str(x)),
            padding='max_length',
            max_length=self.args.max_length,
            truncation=True,
        ))
        return df

    def train_dataloader(self):
        df = self.read_data(self.args.train_data_path)
        df = self.preprocess_dataframe(df)

        dataset = TensorDataset(
            torch.tensor(df['title'].to_list(), dtype=torch.long),
            torch.tensor(df['topic_idx'].to_list(), dtype=torch.long),
        )
        return DataLoader(
            dataset,
            batch_size=self.args.batch_size or self.batch_size,
            shuffle=True,
            num_workers=self.args.cpu_workers,
        )

    def val_dataloader(self):
        df = self.read_data(self.args.val_data_path)
        df = self.preprocess_dataframe(df)

        dataset = TensorDataset(
            torch.tensor(df['title'].to_list(), dtype=torch.long),
            torch.tensor(df['topic_idx'].to_list(), dtype=torch.long),
        )
        return DataLoader(
            dataset,
            batch_size=self.args.batch_size or self.batch_size,
            shuffle=False,
            num_workers=self.args.cpu_workers,
        )
    
    def test_dataloader(self):
        df = self.read_data(self.args.test_data_path)
        df = self.preprocess_dataframe(df)

        dataset = TensorDataset(
            torch.tensor(df['title'].to_list(), dtype=torch.long),
            torch.tensor(df['index'].to_list(), dtype=torch.long),
        )
        return DataLoader(
            dataset,
            batch_size= self.args.batch_size or self.batch_size,
            shuffle=False,
            num_workers=self.args.cpu_workers,
        )

# %%
def main():
    print("Using PyTorch Ver", torch.__version__)
    print("Fix Seed:", args.random_seed)
    seed_everything(args.random_seed)
    model = Model(args)

    print(":: Start Training ::")
    trainer = Trainer(
        max_epochs=args.epochs,
        fast_dev_run=args.test_mode,
        num_sanity_val_steps=None if args.test_mode else 0,
        auto_scale_batch_size=args.auto_batch_size if args.auto_batch_size and not args.batch_size else False,
        # For GPU Setup
        deterministic=torch.cuda.is_available(),
        gpus=-1 if torch.cuda.is_available() else None,
        precision=16 if args.fp16 else 32,
        # For TPU Setup
        # tpu_cores=args.tpu_cores if args.tpu_cores else None,
    )
    trainer.fit(model)
    trainer.test(model)

# %%
torch.cuda.empty_cache()

# %%
main()
# Out:
# Global seed set to 42
# Using PyTorch Ver 1.9.0+cu102
# Fix Seed: 42
# Some weights of the model checkpoint at beomi/kcbert-base were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at beomi/kcbert-base and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using native 16bit precision.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# :: Start Training ::
#   | Name | Type                          | Params
# -------------------------------------------------------
# 0 | bert | BertForSequenceClassification | 108 M
# -------------------------------------------------------
# 108 M     Trainable params
# 0         Non-trainable params
# 108 M     Total params
# 435.696   Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'train_acc': 0.25,
#  'train_f1': 0.1990307486631016,
#  'train_loss': 1.912078857421875,
#  'train_precision': 0.18590686274509804,
#  'train_recall': 0.25}
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'train_acc': 0.53125,
#  'train_f1': 0.5235863095238095,
#  'train_loss': 1.4406890869140625,
#  'train_precision': 0.6305555555555555,
#  'train_recall': 0.53125}
#
# {'train_acc': 0.6875,
#  'train_f1': 0.6903409090909091,
#  'train_loss': 1.015228271484375,
#  'train_precision': 0.7552083333333334,
#  'train_recall': 0.6875}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8028409090909091,
#  'train_loss': 0.5690021514892578,
#  'train_precision': 0.8020833333333333,
#  'train_recall': 0.8125}
#
# {'train_acc': 0.625,
#  'train_f1': 0.6111111111111112,
#  'train_loss': 0.9642868041992188,
#  'train_precision': 0.6046874999999999,
#  'train_recall': 0.625}
#
# {'train_acc': 0.75,
#  'train_f1': 0.7462683150183149,
#  'train_loss': 0.7152571678161621,
#  'train_precision': 0.8154761904761905,
#  'train_recall': 0.75}
#
# {'train_acc': 0.78125,
#  'train_f1': 0.7846320346320346,
#  'train_loss': 0.4221014976501465,
#  'train_precision': 0.8208333333333333,
#  'train_recall': 0.78125}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8744747899159664,
#  'train_loss': 0.49683046340942383,
#  'train_precision': 0.87890625,
#  'train_recall': 0.875}
#
# {'train_acc': 0.78125,
#  'train_f1': 0.7728219696969697,
#  'train_loss': 0.5888853073120117,
#  'train_precision': 0.792075892857143,
#  'train_recall': 0.78125}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8838913690476191,
#  'train_loss': 0.31427812576293945,
#  'train_precision': 0.93515625,
#  'train_recall': 0.875}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9073773448773448,
#  'train_loss': 0.4213290214538574,
#  'train_precision': 0.9203125,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8708400974025973,
#  'train_loss': 0.5529344081878662,
#  'train_precision': 0.9058779761904763,
#  'train_recall': 0.875}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8441572664549337,
#  'val_f1': 0.8446782019548915,
#  'val_loss': 0.4476139545440674,
#  'val_precision': 0.8484678838429619,
#  'val_recall': 0.8441572664549337}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8685399159663866,
#  'train_loss': 0.3843355178833008,
#  'train_precision': 0.9135416666666667,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8710689484126984,
#  'train_loss': 0.5430941581726074,
#  'train_precision': 0.9006076388888888,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9376225490196078,
#  'train_loss': 0.23510408401489258,
#  'train_precision': 0.9583333333333334,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8456730769230769,
#  'train_loss': 0.4792947769165039,
#  'train_precision': 0.8640625,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8295454545454545,
#  'train_loss': 0.5524382591247559,
#  'train_precision': 0.8723958333333334,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8194181839402427,
#  'train_loss': 0.46404480934143066,
#  'train_precision': 0.8666666666666667,
#  'train_recall': 0.8125}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.12255120277404785,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8277777777777777,
#  'train_loss': 0.5209342241287231,
#  'train_precision': 0.82265625,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.12652039527893066,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9043803418803418,
#  'train_loss': 0.36111128330230713,
#  'train_precision': 0.9072916666666667,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8114583333333334,
#  'train_loss': 0.4101881980895996,
#  'train_precision': 0.8303571428571428,
#  'train_recall': 0.8125}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9080424783549783,
#  'train_loss': 0.4381653070449829,
#  'train_precision': 0.9364583333333334,
#  'train_recall': 0.90625}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.851713941517906,
#  'val_f1': 0.8521961981110451,
#  'val_loss': 0.4285183250904083,
#  'val_precision': 0.8560755212672169,
#  'val_recall': 0.851713941517906}
#
# {'train_acc': 0.875,
#  'train_f1': 0.875185057997558,
#  'train_loss': 0.4652256965637207,
#  'train_precision': 0.9169642857142857,
#  'train_recall': 0.875}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9071428571428573,
#  'train_loss': 0.3319528102874756,
#  'train_precision': 0.9375,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9236111111111112,
#  'train_loss': 0.323050856590271,
#  'train_precision': 0.9169642857142857,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.8980769230769231,
#  'train_loss': 0.25660812854766846,
#  'train_precision': 0.9315476190476191,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.915625,
#  'train_loss': 0.2687571048736572,
#  'train_precision': 0.9583333333333333,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9375,
#  'train_loss': 0.21644461154937744,
#  'train_precision': 0.9553571428571429,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9363095238095238,
#  'train_loss': 0.17588543891906738,
#  'train_precision': 0.94921875,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9069407155344655,
#  'train_loss': 0.3638392686843872,
#  'train_precision': 0.9253472222222222,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.7984126984126985,
#  'train_loss': 0.44646143913269043,
#  'train_precision': 0.8536458333333333,
#  'train_recall': 0.8125}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8458333333333333,
#  'train_loss': 0.5225270986557007,
#  'train_precision': 0.8541666666666667,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8711489898989899,
#  'train_loss': 0.3393540382385254,
#  'train_precision': 0.87734375,
#  'train_recall': 0.875}
#
# {'train_acc': 0.78125,
#  'train_f1': 0.7879245448179271,
#  'train_loss': 0.47472143173217773,
#  'train_precision': 0.8319196428571428,
#  'train_recall': 0.78125}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8669368086737488,
#  'val_f1': 0.8660843471383844,
#  'val_loss': 0.3909376859664917,
#  'val_precision': 0.8662992912712085,
#  'val_recall': 0.8669368086737488}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9096840659340659,
#  'train_loss': 0.2627558708190918,
#  'train_precision': 0.9341517857142857,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9396416083916084,
#  'train_loss': 0.10259974002838135,
#  'train_precision': 0.953125,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8729166666666666,
#  'train_loss': 0.28857600688934326,
#  'train_precision': 0.8911830357142857,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8729482323232323,
#  'train_loss': 0.42815297842025757,
#  'train_precision': 0.8864583333333333,
#  'train_recall': 0.875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.2399284839630127,
#  'train_precision': 0.9765625,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8433379120879121,
#  'train_loss': 0.37157052755355835,
#  'train_precision': 0.8604910714285714,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9083333333333332,
#  'train_loss': 0.2611902356147766,
#  'train_precision': 0.9397321428571429,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9059027777777777,
#  'train_loss': 0.2354753017425537,
#  'train_precision': 0.9203125,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9706730769230769,
#  'train_loss': 0.14436036348342896,
#  'train_precision': 0.9791666666666666,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8731286075036075,
#  'train_loss': 0.3961069583892822,
#  'train_precision': 0.8932291666666667,
#  'train_recall': 0.875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9670454545454545,
#  'train_loss': 0.08396255970001221,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.847005772005772,
#  'train_loss': 0.3160663843154907,
#  'train_precision': 0.8697916666666666,
#  'train_recall': 0.84375}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8651845361953784,
#  'val_f1': 0.8650111464243407,
#  'val_loss': 0.40275540947914124,
#  'val_precision': 0.8660126864565038,
#  'val_recall': 0.8651845361953784}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9038825757575757,
#  'train_loss': 0.19083917140960693,
#  'train_precision': 0.9229166666666667,
#  'train_recall': 0.90625}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.04355216026306152,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.11819672584533691,
#  'train_precision': 0.975,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8770292207792209,
#  'train_loss': 0.2133321762084961,
#  'train_precision': 0.8854166666666666,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8558894230769232,
#  'train_loss': 0.32444727420806885,
#  'train_precision': 0.9107142857142857,
#  'train_recall': 0.875}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8803685897435898,
#  'train_loss': 0.40668439865112305,
#  'train_precision': 0.900297619047619,
#  'train_recall': 0.875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9373397435897435,
#  'train_loss': 0.20428937673568726,
#  'train_precision': 0.9583333333333333,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9695616883116882,
#  'train_loss': 0.10966330766677856,
#  'train_precision': 0.9765625,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9683712121212121,
#  'train_loss': 0.21482372283935547,
#  'train_precision': 0.97265625,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.8125,
#  'train_f1': 0.8192640692640691,
#  'train_loss': 0.5622727870941162,
#  'train_precision': 0.8484375,
#  'train_recall': 0.8125}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.937280701754386,
#  'train_loss': 0.11131024360656738,
#  'train_precision': 0.9484375,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9696428571428571,
#  'train_loss': 0.08288419246673584,
#  'train_precision': 0.9791666666666666,
#  'train_recall': 0.96875}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8629941955974154,
#  'val_f1': 0.8629684195717634,
#  'val_loss': 0.4217126965522766,
#  'val_precision': 0.8634089472849099,
#  'val_recall': 0.8629941955974154}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9649621212121212,
#  'train_loss': 0.1210833191871643,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.043702900409698486,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9366883116883117,
#  'train_loss': 0.1543177366256714,
#  'train_precision': 0.9427083333333334,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9670454545454545,
#  'train_loss': 0.06335222721099854,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9061274509803922,
#  'train_loss': 0.3182145357131958,
#  'train_precision': 0.9253472222222222,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.19685667753219604,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9370659722222223,
#  'train_loss': 0.1850687563419342,
#  'train_precision': 0.95,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9098214285714286,
#  'train_loss': 0.28783196210861206,
#  'train_precision': 0.9174107142857143,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9682539682539683,
#  'train_loss': 0.13648948073387146,
#  'train_precision': 0.975,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8512896825396825,
#  'train_loss': 0.5670104026794434,
#  'train_precision': 0.8958333333333334,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.93989898989899,
#  'train_loss': 0.3097483515739441,
#  'train_precision': 0.9541666666666666,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.875,
#  'train_f1': 0.8675213675213675,
#  'train_loss': 0.505139946937561,
#  'train_precision': 0.8732142857142857,
#  'train_recall': 0.875}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8639798488664987,
#  'val_f1': 0.8646161031313977,
#  'val_loss': 0.4486323595046997,
#  'val_precision': 0.8666472003581406,
#  'val_recall': 0.8639798488664987}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9079545454545455,
#  'train_loss': 0.1375381052494049,
#  'train_precision': 0.921875,
#  'train_recall': 0.90625}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.07792249321937561,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.8952020202020201,
#  'train_loss': 0.275301992893219,
#  'train_precision': 0.9229166666666667,
#  'train_recall': 0.90625}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9030637254901962,
#  'train_loss': 0.3125153183937073,
#  'train_precision': 0.934375,
#  'train_recall': 0.90625}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.032930657267570496,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9668269230769231,
#  'train_loss': 0.08551502227783203,
#  'train_precision': 0.9732142857142857,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9684343434343434,
#  'train_loss': 0.08182157576084137,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9666666666666667,
#  'train_loss': 0.1472790539264679,
#  'train_precision': 0.9791666666666666,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9697802197802198,
#  'train_loss': 0.10319346189498901,
#  'train_precision': 0.9765625,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9708333333333333,
#  'train_loss': 0.12841518223285675,
#  'train_precision': 0.9791666666666667,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.969128787878788,
#  'train_loss': 0.10180434584617615,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9041486291486291,
#  'train_loss': 0.25764787197113037,
#  'train_precision': 0.9270833333333334,
#  'train_recall': 0.90625}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8569707589530172,
#  'val_f1': 0.8566834072440963,
#  'val_loss': 0.4932239353656769,
#  'val_precision': 0.8584545262787052,
#  'val_recall': 0.8569707589530172}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9377828054298643,
#  'train_loss': 0.27878743410110474,
#  'train_precision': 0.9497767857142857,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9673611111111111,
#  'train_loss': 0.09466984868049622,
#  'train_precision': 0.975,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.07673193514347076,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9689685314685315,
#  'train_loss': 0.14189577102661133,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.027956858277320862,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.061624884605407715,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.07094481587409973,
#  'train_precision': 0.9732142857142857,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9652777777777778,
#  'train_loss': 0.06783206760883331,
#  'train_precision': 0.975,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.120672807097435,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9370039682539683,
#  'train_loss': 0.15241007506847382,
#  'train_precision': 0.94375,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9263392857142857,
#  'train_loss': 0.11151546239852905,
#  'train_precision': 0.953125,
#  'train_recall': 0.9375}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.06368589401245117,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8601467528200635,
#  'val_f1': 0.8604461292253073,
#  'val_loss': 0.5043538212776184,
#  'val_precision': 0.8612078829438675,
#  'val_recall': 0.8601467528200635}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.03081396222114563,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.0128994882106781,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.84375,
#  'train_f1': 0.8708218864468864,
#  'train_loss': 0.2311999499797821,
#  'train_precision': 0.9140625,
#  'train_recall': 0.84375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9673611111111111,
#  'train_loss': 0.10764269530773163,
#  'train_precision': 0.975,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.03732798993587494,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.936587024087024,
#  'train_loss': 0.14891505241394043,
#  'train_precision': 0.9458705357142857,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9665441176470588,
#  'train_loss': 0.15894268453121185,
#  'train_precision': 0.9722222222222222,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9665441176470588,
#  'train_loss': 0.11126047372817993,
#  'train_precision': 0.9722222222222222,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9385302197802197,
#  'train_loss': 0.12813887000083923,
#  'train_precision': 0.9505208333333334,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.10007867962121964,
#  'train_precision': 0.9739583333333334,
#  'train_recall': 0.96875}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9386113886113885,
#  'train_loss': 0.11890006810426712,
#  'train_precision': 0.953125,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.90625,
#  'train_f1': 0.9130140692640693,
#  'train_loss': 0.16761797666549683,
#  'train_precision': 0.94375,
#  'train_recall': 0.90625}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8574088270726098,
#  'val_f1': 0.8569146067046436,
#  'val_loss': 0.5466322302818298,
#  'val_precision': 0.8575381362040155,
#  'val_recall': 0.8574088270726098}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9677197802197802,
#  'train_loss': 0.0604904443025589,
#  'train_precision': 0.9732142857142857,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.010014526546001434,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.022226348519325256,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.96875,
#  'train_loss': 0.07058361917734146,
#  'train_precision': 0.984375,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.022254571318626404,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.031977273523807526,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.9375,
#  'train_f1': 0.9392361111111112,
#  'train_loss': 0.10896511375904083,
#  'train_precision': 0.9541666666666666,
#  'train_recall': 0.9375}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9695616883116883,
#  'train_loss': 0.19191709160804749,
#  'train_precision': 0.9765625,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.027578279376029968,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9675595238095238,
#  'train_loss': 0.12724095582962036,
#  'train_precision': 0.97265625,
#  'train_recall': 0.96875}
#
# {'train_acc': 1.0,
#  'train_f1': 1.0,
#  'train_loss': 0.027005352079868317,
#  'train_precision': 1.0,
#  'train_recall': 1.0}
#
# {'train_acc': 0.96875,
#  'train_f1': 0.9680735930735931,
#  'train_loss': 0.08054010570049286,
#  'train_precision': 0.9715909090909091,
#  'train_recall': 0.96875}
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# {'val_acc': 0.8575183441025079,
#  'val_f1': 0.8576778741356343,
#  'val_loss': 0.5725070834159851,
#  'val_precision': 0.8582125680292672,
#  'val_recall': 0.8575183441025079}
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {}
# --------------------------------------------------------------------------------

# %%
submit = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/sample_submission.csv')
prediction = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/prediction.csv')

# %%
submit['topic_idx']= prediction['0']

# %%
submit
# Out:
#       index  topic_idx
# 0     45654          2
# 1     45655          3
# 2     45656          2
# 3     45657          2
# 4     45658          3
# ...     ...        ...
# 9126  54780          3
# 9127  54781          2
# 9128  54782          2
# 9129  54783          2
# 9130  54784          6
#
# [9131 rows x 2 columns]

# %%
submit.to_csv('/content/drive/My Drive/Colab Notebooks/Dacon_news/bert_submission.csv', index = False)

# %%
torch.save(main,'/content/drive/My Drive/Colab Notebooks/Dacon_news/bert_model.pt')

# %% [markdown]
# Score 10epoch 80/20: 0.8205914567
